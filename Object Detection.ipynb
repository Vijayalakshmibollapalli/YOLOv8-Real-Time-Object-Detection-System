# %%
# !pip install ultralytics opencv-python pillow --user

# %% [markdown]
# ## Import Libraries

# %%
import cv2
import time
from ultralytics import YOLO
from IPython.display import display, clear_output
from PIL import Image
import numpy as np
import PIL.Image

# %% [markdown]
# ## Load YOLO Model

# %%
# model = YOLO("yolov8s.pt")
model = YOLO("yolov8n.pt")  # faster, smoother
print("YOLO working")
# Out:
# YOLO working

# %% [markdown]
# ## YOLO Webcam Code

# %%
# Start webcam
cap = cv2.VideoCapture(0)

# Create fullscreen window
cv2.namedWindow("YOLO AI Detection System", cv2.WINDOW_NORMAL)
cv2.setWindowProperty("YOLO AI Detection System", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

prev_time = 0
record = False
video_writer = None

while True:

    # Read frame
    ret, frame = cap.read()
    if not ret:
        break

    # YOLO detection + tracking
    results = model.track(frame, persist=True, conf=0.50)

    # Draw detection boxes
    frame = results[0].plot()

    # Object counting
    object_count = {}
    
    if results[0].boxes is not None:
        classes = results[0].boxes.cls.tolist()
        names = model.names

        for cls in classes:
            label = names[int(cls)]
            object_count[label] = object_count.get(label, 0) + 1

    # FPS calculation
    curr_time = time.time()
    fps = 1/(curr_time-prev_time) if prev_time != 0 else 0
    prev_time = curr_time

    # Display FPS
    cv2.putText(frame,
                f"FPS: {int(fps)}",
                (20,40),
                cv2.FONT_HERSHEY_SIMPLEX,
                1,
                (0,255,0),
                2)

    # Display object counts
    y_offset = 80
    for obj,count in object_count.items():

        cv2.putText(frame,
                    f"{obj}: {count}",
                    (20,y_offset),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.7,
                    (255,0,0),
                    2)

        y_offset += 30
    
     # Video recording
    if record:
        if video_writer is None:
            fourcc = cv2.VideoWriter_fourcc(*'XVID')
            video_writer = cv2.VideoWriter(
                "output.avi", fourcc, 20.0,
                (frame.shape[1], frame.shape[0])
            )
        video_writer.write(frame)

    # Show frame in fullscreen
    cv2.imshow("YOLO AI Detection System", frame)

    # Keyboard controls
    key = cv2.waitKey(1) & 0xFF

    # Quit
    if key == ord('q'):
        break

    # Screenshot
    if key == ord('s'):
        filename = f"screenshot_{int(time.time())}.jpg"
        cv2.imwrite(filename, frame)
        print("Screenshot saved:", filename)

    # Toggle recording
    if key == ord('r'):
        record = not record
        print("Recording:", record)

# Release camera
cap.release()

if video_writer:
    video_writer.release()

cv2.destroyAllWindows()
# Out:
# WARNING not enough matching points
# 0: 480x640 (no detections), 174.7ms
# Speed: 57.7ms preprocess, 174.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING not enough matching points
# 0: 480x640 (no detections), 83.2ms
# Speed: 2.8ms preprocess, 83.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING not enough matching points
# 0: 480x640 (no detections), 67.9ms
# Speed: 1.9ms preprocess, 67.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING not enough matching points
# 0: 480x640 (no detections), 62.7ms
# Speed: 1.4ms preprocess, 62.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING not enough matching points
# 0: 480x640 (no detections), 62.9ms
# Speed: 2.8ms preprocess, 62.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING not enough matching points
# 0: 480x640 (no detections), 59.6ms
# Speed: 1.7ms preprocess, 59.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING not enough matching points
# 0: 480x640 (no detections), 57.2ms
# Speed: 1.6ms preprocess, 57.2ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING not enough matching points
# 0: 480x640 (no detections), 58.6ms
# Speed: 3.7ms preprocess, 58.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING not enough matching points
# 0: 480x640 (no detections), 51.5ms
# Speed: 2.7ms preprocess, 51.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.5ms
# Speed: 4.4ms preprocess, 59.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.7ms
# Speed: 1.5ms preprocess, 51.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.5ms
# Speed: 1.9ms preprocess, 52.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 72.8ms
# Speed: 1.9ms preprocess, 72.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.2ms
# Speed: 3.1ms preprocess, 55.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.1ms
# Speed: 2.7ms preprocess, 53.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.0ms
# Speed: 1.7ms preprocess, 60.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# ### Yolo detection by Image

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model(r"C:\Users\B VIJAYA LAKSHMI\Object Detection Yolo\Object Pic 1.jpg")
results[0].show()
# Out:
# image 1/1 C:\Users\B VIJAYA LAKSHMI\Object Detection Yolo\Object Pic 1.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 167.8ms
# Speed: 5.2ms preprocess, 167.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model(r"C:\Users\B VIJAYA LAKSHMI\Object Detection Yolo\Object Pic 2.jpg")
results[0].show()
# Out:
# image 1/1 C:\Users\B VIJAYA LAKSHMI\Object Detection Yolo\Object Pic 2.jpg: 640x640 6 persons, 2 handbags, 1 suitcase, 502.4ms
# Speed: 12.7ms preprocess, 502.4ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model(r"C:\Users\B VIJAYA LAKSHMI\Object Detection Yolo\Object Pic 3.webp")
results[0].show()
# Out:
# image 1/1 C:\Users\B VIJAYA LAKSHMI\Object Detection Yolo\Object Pic 3.webp: 384x640 3 cars, 3 buss, 336.3ms
# Speed: 5.7ms preprocess, 336.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)

# %%
import cv2
from ultralytics import YOLO

# Load image
image_path = r"C:\Users\B VIJAYA LAKSHMI\Object Detection Yolo\Object Pic 3.webp"
img = cv2.imread(image_path)

# Show ORIGINAL image
cv2.imshow("Original Image", img)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model(r"C:\Users\B VIJAYA LAKSHMI\Object Detection Yolo\Object Pic 3.webp")
results[0].show()
# Out:
# image 1/1 C:\Users\B VIJAYA LAKSHMI\Object Detection Yolo\Object Pic 3.webp: 384x640 3 cars, 3 buss, 282.7ms
# Speed: 7.7ms preprocess, 282.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
